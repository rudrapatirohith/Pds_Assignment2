# %%
import pandas as pd
from datetime import datetime

# %%
# Load the dataset
data = pd.read_csv(r"C:\Users\rudra\Downloads\train.csv")

# %%
cols = data.columns

# %%
del data[cols[0]]

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 1                      Honda Jazz V     Chennai  2011              46000
# 2                 Maruti Ertiga VDI     Chennai  2012              87000
# 3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 4            Nissan Micra Diesel XV      Jaipur  2013              86999
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 1    Petrol       Manual      First    13 km/kg  1199 CC   88.7 bhp    5.0
# 2    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 3    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# 4    Diesel       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0
#
#    New_Price  Price
# 0        NaN  12.50
# 1  8.61 Lakh   4.50
# 2        NaN   6.00
# 3        NaN  17.74
# 4        NaN   3.50

# %% [markdown]
#
#
# # a) Handling Missing Values:
# # Check for missing values

# %%
missing_values_in_each_col = data.isnull().sum()
missing_values_in_each_col
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %% [markdown]
# # b) Removing Units: we have to do this before we start doing part a.

# %%
data['Mileage'] = data['Mileage'].str.extract('(\d+\.\d+)').astype(float)
data['Engine'] = data['Engine'].str.extract('(\d+)').astype(float)
data['Power'] = data['Power'].str.extract('(\d+\.\d+)').astype(float)
data['New_Price'] = data['New_Price'].str.extract('(\d+)').astype(float)

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 1                      Honda Jazz V     Chennai  2011              46000
# 2                 Maruti Ertiga VDI     Chennai  2012              87000
# 3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 4            Nissan Micra Diesel XV      Jaipur  2013              86999
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 1    Petrol       Manual      First      NaN  1199.0   88.70    5.0
# 2    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 3    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
# 4    Diesel       Manual      First    23.08  1461.0   63.10    5.0
#
#    New_Price  Price
# 0        NaN  12.50
# 1        8.0   4.50
# 2        NaN   6.00
# 3        NaN  17.74
# 4        NaN   3.50

# %% [markdown]
# # a)continuation from above : # Impute missing values

# %%
data['Mileage'].fillna(data['Mileage'].mean(), inplace=True)
data['Engine'].fillna(data['Engine'].mean(), inplace=True)
data['Power'].fillna(data['Power'].mean(), inplace=True)
data['Seats'].fillna(data['Seats'].median(), inplace=True)
data['New_Price'].fillna(data['New_Price'].median(), inplace=True)

# %% [markdown]
# # Drop rows with missing values in other columns

# %%
data.dropna(inplace=True)

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  5847.000000       5.847000e+03  5847.000000  5847.000000  5847.000000
# mean   2013.448435       5.841013e+04    18.159379  1631.552573   107.352151
# std       3.194949       9.237971e+04     4.356978   600.116234    36.892226
# min    1998.000000       1.710000e+02     0.000000    72.000000    34.200000
# 25%    2012.000000       3.346750e+04    15.260000  1198.000000    86.800000
# 50%    2014.000000       5.257600e+04    18.190000  1497.000000   107.352151
# 75%    2016.000000       7.249050e+04    21.100000  1991.000000   107.352151
# max    2019.000000       6.500000e+06    28.400000  5998.000000   488.100000
#
#              Seats    New_Price        Price
# count  5847.000000  5847.000000  5847.000000
# mean      5.284590    12.253805     9.653742
# std       0.804372     8.174116    11.275966
# min       2.000000     1.000000     0.440000
# 25%       5.000000    11.000000     3.550000
# 50%       5.000000    11.000000     5.750000
# 75%       5.000000    11.000000    10.250000
# max      10.000000    99.000000   160.000000

# %%
data.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# New_Price            float64
# Price                float64
# dtype: object

# %%
data.head(1)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats  New_Price  \
# 0    Diesel       Manual      First    19.67  1582.0  126.2    5.0       11.0
#
#    Price
# 0   12.5

# %%
# saving the cleaned data into a csv file
data.to_csv(r'C:\Users\rudra\OneDrive\Desktop\PDS_ASSIGNMENT2\cleandata\processeddata.csv')

# %% [markdown]
# # a) #Justification for the action of this task:
#
# Handling missing values means deciding what to do with the empty spots in your data. You can either fill these gaps with average values from other data points or remove the entire rows with missing values. The choice depends on how much data is missing and the impact on your analysis.

# %% [markdown]
# # c) One-Hot Encoding Categorical Variables:

# %%
data = pd.get_dummies(data, columns=['Fuel_Type', 'Transmission'], prefix=['Fuel_Type', 'Transmission'])

# %%
data.head(1)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Owner_Type  Mileage  Engine  Power  Seats  New_Price  Price  \
# 0      First    19.67  1582.0  126.2    5.0       11.0   12.5
#
#    Fuel_Type_Diesel  Fuel_Type_Electric  Fuel_Type_Petrol  \
# 0                 1                   0                 0
#
#    Transmission_Automatic  Transmission_Manual
# 0                       0                    1

# %% [markdown]
# # d) Creating a New Feature (Average Mileage Per Year):

# %%
data['Avg_Mileage_Per_Year'] = data['Mileage'] / data['Current_Age']

# %%
data.to_csv(r"C:\Users\rudra\Downloads\train_preprocessed.csv", index=False)
